# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets import load_iris
from sklearn.decomposition import PCA

# %%
iris_data = load_iris()

# %%
data = iris_data.data
feature_names = iris_data.feature_names
y = iris_data.target

# %%
df = pd.DataFrame(data, columns=feature_names)
df["class"] = y
df.head(3)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
#
#    class
# 0      0
# 1      0
# 2      0

# %%
pca = PCA(n_components=2,whiten=True)

# %%
pca.fit(data)
# Out:
# PCA(n_components=2, whiten=True)

# %%
x_pca = pca.transform(data)

# %%
variance_ratio = pca.explained_variance_ratio_
print(f"Variance Ration: {variance_ratio}")
print(f"Sum: {sum(variance_ratio)}")
# Out:
# Variance Ration: [0.92461872 0.05306648]
# Sum: 0.977685206318798

# %%
df["p1"] = x_pca[:,0]
df["p2"] = x_pca[:,1]

color = ["red","green","blue"]

for each in range(3):
    plt.scatter(df.p1[df["class"] == each],df.p2[df["class"] == each],color = color[each],label = iris_data.target_names[each])

plt.legend()
plt.xlabel("p1")
plt.ylabel("p2")
plt.title("Iris Dataset - Reduction to 2D with PCA")
plt.show()
