# %% [markdown]
# | Algoritma   | KMeans       | DBSCAN       |
# |-------------|--------------|--------------|
# | Tür         | Merkez tabanlı kümeleme | Yoğunluk tabanlı kümeleme |
# | Parametreler| Küme sayısı (k) | MinPts, epsilon |
# | Esneklik    | Sabit küme sayısı, küme boyutu ve şekli | Esnek küme sayısı, değişen küme boyutu ve şekli |
# | Gürültü     | Gürültüye duyarlı | Gürültüye karşı dirençli |
# | Performans  | Genellikle yüksek boyutlu verilerde iyi çalışır | Yoğunluklu bölgelerde iyi çalışır, küme sayısını belirlemek için daha az duyarlı |
# ![PicsArt_11-17-08.07.10-300x300.jpg](data:image/jpeg;base64,...)
